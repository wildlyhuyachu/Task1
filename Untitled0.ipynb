# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# # **1. выведите размер таблицы**

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # **2. выведите первые 5 строкa**

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # **3. выведите последние 5 строк**

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # **4. выведите случайные 10 строк**

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 70            71         0       2
# 840          841         0       3
# 667          668         0       3
# 96            97         0       1
# 525          526         0       3
# 262          263         0       1
# 518          519         1       2
# 543          544         1       2
# 403          404         0       3
# 233          234         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 70                          Jenkin, Mr. Stephen Curnow    male  32.0      0
# 840                        Alhomaki, Mr. Ilmari Rudolf    male  20.0      0
# 667                         Rommetvedt, Mr. Knud Paust    male   NaN      0
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 525                                 Farrell, Mr. James    male  40.5      0
# 262                                  Taussig, Mr. Emil    male  52.0      1
# ...

# %% [markdown]
# # **5. создайте 2 копии таблицы (Дале “копия1” и “копия2”)**

# %%
copy1 = df.copy()

# %%
copy2 = df.copy()

# %% [markdown]
# # **6. выведите информацию о таблице “копия1”, выберите столбец с пропущенными значениями (они же “null”, они же “NaN”) и удалите их, выведите информацию об этой таблице снова.**

# %%
copy2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
copy1.dropna(subset=["Cabin"], inplace = True)

# %%
copy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  204 non-null    int64
#  1   Survived     204 non-null    int64
#  2   Pclass       204 non-null    int64
#  3   Name         204 non-null    object
#  4   Sex          204 non-null    object
#  5   Age          185 non-null    float64
#  6   SibSp        204 non-null    int64
#  7   Parch        204 non-null    int64
#  8   Ticket       204 non-null    object
#  9   Fare         204 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     202 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 20.7+ KB

# %% [markdown]
#  # **7. выведите информацию о таблице “копия2”, выберите столбец с пропущенными значениями (они же “null”, они же “NaN”) и замените их на что-нибудь, выведите информацию об этой таблице снова.**

# %%
copy2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
copy2.loc[:,"Age"].fillna("Undentificated", inplace = True)

# %%
copy2.Age
# Out:
# 0                22.0
# 1                38.0
# 2                26.0
# 3                35.0
# 4                35.0
#             ...
# 886              27.0
# 887              19.0
# 888    Undentificated
# 889              26.0
# 890              32.0
# Name: Age, Length: 891, dtype: object

# %% [markdown]
# # **8. В любой таблице выберите столбец с числами и найдите его среднее значение**

# %%
copy2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# ...

# %%
copy1.Age.mean()
# Out:
# 35.829297297297295

# %% [markdown]
# # **9 . в любой таблице выберите столбец с категориальными данными (как правило строки) и выведите количество его уникальных значений**

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # **10.в любой таблице измените значение любой колонки длявторого и третьего объектов (объект = строка). выведите результаты, что бы убедиться, что изменения сохранились.**

# %%
df.loc[2:3, "Sex"] = ["Dont like", "Interested in"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name            Sex   Age  \
# 0                            Braund, Mr. Owen Harris           male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         female  38.0
# 2                             Heikkinen, Miss. Laina      Dont like  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Interested in  35.0
# 4                           Allen, Mr. William Henry           male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# # **11. создайте две маленькие таблицы 3х3 и соедините их в одну**

# %%
new_df = pd.DataFrame ({"Username":["Denchik","Afoniy","Mityay"],"Ryodan id":[69,1337,4],})

# %%
new_df
# Out:
#   Username  Ryodan id
# 0  Denchik         69
# 1   Afoniy       1337
# 2   Mityai          4

# %%
new_df1 = pd.DataFrame ({"Username":["Kyarnk","Shipchunchik","Namsr"],"Ryodan id":[2,47,96],})

# %%
new_df1
# Out:
#        Username  Ryodan id
# 0        Kyarnk          2
# 1  Shipchunchik         47
# 2         Namsr         96

# %%
final_df = pd.concat([new_df,new_df1]).reset_index()
final_df
# Out:
#    index      Username  Ryodan id
# 0      0       Denchik         69
# 1      1        Afoniy       1337
# 2      2        Mityay          4
# 3      0        Kyarnk          2
# 4      1  Shipchunchik         47
# 5      2         Namsr         96

# %% [markdown]
# # **12.сохраните получившуюся таблицу в формате csv**

# %%
final_df.to_csv("name.csv")
